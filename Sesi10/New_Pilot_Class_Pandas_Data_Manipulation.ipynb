# %% [markdown]
# <a href="https://colab.research.google.com/github/yumnazakkiya/DQLAB_DATA_ANALYST/blob/main/Sesi10/New_Pilot_Class_Pandas_Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**
#
# Sebelum sebuah data dapat dianalisis atau digunakan untuk mengambil keputusan kebijakan tentu data tersebut perlu untuk diekstraksi terlebih dahulu. <b>Ekstraksi data</b> adalah sebuah proses pengumpulan atau pengambilan jenis data yang berbeda dari berbagai sumber, banyak di antaranya mungkin tidak terorganisir dengan baik atau tidak terstruktur sama sekali. Proses ini memungkinkan untuk mengkonsolidasikan, memproses, dan menyempurnakan data sehingga nantinya dapat disimpan di lokasi terpusat untuk diubah atau diproses lebih lanjut.
#
# Python sebagai salah satu <i>tools</i> yang <i>powerful</i> untuk pengolahan data menyediakan berbagai <i>library</i> untuk mendukung proses ekstraksi data. Salah satu library paling banyak digunakan adalah <b>pandas</b>.
#
# Pandas memungkinkan untuk membaca data dari berbagai jenis ekstensi seperti data yang bersumber dari database (sql), <i>excel</i> (<b>.xls</b> atau <b>.xlsx</b>), <i>separated value file</i> (<b>.csv</b>, <b>.tsv</b>, dsb) lalu merubahnya menjadi satu format struktur data yang sama yang disebut <b>DataFrame</b>. DataFrame inilah yang nantinya dapat kita lakukan proses <b>Data Manipulation</b><br><br>
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=18NW3gMMTJjkwwpZX5TXi9DTteXxGAoxa" width="600" height="300">
# <p align="center"><b>Gambar 1. Proses Ekstraksi Data dengan <i>pandas</i></b></p>
#
# <br><br>
# <p align="right"><sup>docs : <i><a href="https://shorturl.at/xyZ69">https://pandas.pydata.org/docs/user_guide/io.html</i></sup></a></p>

# %% [markdown]
# ##**1. First Step : Pandas**
#
# Untuk dapat menggunakan library pandas pada python, perlu untuk mengimpor library tersebut dengan cara mengetikan sintaks berikut
#
# <p align="center"><code><b>import pandas as pd</b></code></p>
#
# lalu jalankan (<i>run</i>) program.
#
# <br><br>
# <p align="left"><sup>docs : <i><a href="https://shorturl.at/kzG06">https://pandas.pydata.org/docs/getting_started/install.html</i></sup></a></p>

# %% [markdown]
# ### 👨‍💻 Task 1
#
# Ketikan kode `import pandas as pd` pada prompt dibawah ini lalu jalankan

# %%
# Write your code below here & exec!
import pandas as pd

# %% [markdown]
# # **Struktur Data Pandas**
#
# * Terdapat dua struktur data utama pada library pandas yang disebut dengan Series dan DataFrame.
# <p align="center">
# <img src="https://datagy.io/wp-content/uploads/2022/12/Understanding-Pandas-Series-and-DataFrames-1024x576.png" width="550" height="289">
# <p align="center"><b>Gambar 2. Series VS DataFrame</b></p>
# <br>
#
# * Gabungan beberapa Series yang mempunyai banyak baris yang sama dapat membentuk sebuah DataFrame atau berlaku sebaliknya pada sebuah DataFrame dapat dipecah (di-<i>slicing</i> satu kolom) membentuk sebuah Series.<br><br>
#
# <p align="right"><sup>docs : <i><a href="https://shorturl.at/dezQY">http://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html</i></sup></a></p>

# %% [markdown]
# ##**2. Series**
#
# * <a href="">Series</a> merupakan kolom dari sebuah tabel yang bersifat homogen atau mempunyai elemen dengan tipe data yang sejenis.
#
# * Untuk membuat Series gunakan sintaks berikut
#
# <p align="center"><code><b>pd.Series(data)</b></code></p>
#
# <ul>
#   data dapat berupa <i>array-like</i>, <i>Iterable</i>, <i>dict</i>, atau <i>scalar</i>
# </ul>
#
# <p align="right"><sup>docs : <i><a href=https://pandas.pydata.org/docs/reference/api/pandas.Series.html>https://pandas.pydata.org/docs/reference/api/pandas.Series.html</i></sup></a></p>

# %% [markdown]
# ### 👨‍💻 Task 2 - A
#
# <i>Age of Accounts Receivable</i> (Aging AR) adalah istilah yang merujuk pada lamanya piutang dagang yang masih belum tertagih pada suatu periode tertentu. DQTech mecatat distribusi Aging AR tersaji dari list data sebagai berikut \[78, 91, 40, 50, 95\].
#
# Dari data tersebut buatlah sebuah Series yang disimpan pada variabel dengan nama `ar_aging` lalu tampilkan outputnya!

# %%
# Inisialisasi data
data_age_of_AR = [78, 91, 40, 50, 95]

# Write your code below here & exec!
ar_aging = pd.Series(data_age_of_AR)


# Menampilkan hasil
display(ar_aging)
# Out:
# 0    78
# 1    91
# 2    40
# 3    50
# 4    95
# dtype: int64

# %%
data_age_of_AR = [78, 91, 40, 50, 95]
print(type(data_age_of_AR))
# Out:
# <class 'list'>

# %%
print(type(ar_aging))
# Out:
# <class 'pandas.core.series.Series'>

# %%
ar_aging
# Out:
# 0    78
# 1    91
# 2    40
# 3    50
# 4    95
# dtype: int64

# %% [markdown]
# #### _Apakah fungsi `type` yang merupakan fungsi bawaan python bisa digunakan untuk memeriksa tipe data variabel ar_aging (yang notabennya tipe data buatan / bawaan library lain)?_

# %%
# Inspeksi tipe data
print(type(ar_aging))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### 👨‍💻 Task 2 - B
#
# Dari data Aging AR yang tercatat, akan diberi detail data sebagai berikut
# * Cust 1 memiliki Aging AR sebesar 78
# * Cust 2 memiliki Aging AR sebesar 91
# * Cust 3 memiliki Aging AR sebesar 40
# * Cust 4 memiliki Aging AR sebesar 50
# * Cust 5 memiliki Aging AR sebesar 95
#
# Dari data tersebut buatlah sebuah Series yang disimpan pada variabel dengan nama `detail_ar_aging` lalu tampilkan outputnya!

# %%
 # Inisialisasi data
data_age_of_AR = {
    'Cust1' : 78,
    'Cust2' : 91,
    'Cust3' : 40,
    'Cust4' : 50,
    'Cust5' : 95
}
# Write your code below here & exec!
detail_ar_aging = pd.Series(data_age_of_AR)
# Tampilkan hasilnya
display(detail_ar_aging)
# Out:
# Cust1    78
# Cust2    91
# Cust3    40
# Cust4    50
# Cust5    95
# dtype: int64

# %% [markdown]
# ## **3. DataFrame**
#
# * <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame">DataFrame</a> adalah struktur data 2 dimensi yang terdiri dari baris dan kolom (seperti tabel) dan dapat menyimpan data dari berbagai jenis (termasuk karakter, bilangan bulat, bilangan real, data kategorikal, dan lainnya).
#
# <p align="center">
# <img src="https://www.w3resource.com/w3r_images/pandas-data-frame.svg" width="600" height="300">
# <p align="center"><b>Gambar 2. DataFrame Pandas</b></p>
# <br>
#
# * <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.html#pandas.Series">Series</a> merupakan kolom dari sebuah tabel yang bersifat homogen atau mempunyai elemen dengan tipe data yang sejenis.
#
#
# <p align="center">
# <img src="https://datagy.io/wp-content/uploads/2022/12/Understanding-Pandas-Series-and-DataFrames-1024x576.png" width="550" height="300">
# <p align="center"><b>Gambar 3. Series VS DataFrame</b></p>
# <br>
#
# * Gabungan beberapa Series yang mempunyai banyak baris yang sama dapat membentuk sebuah DataFrame atau berlaku sebaliknya pada sebuah DataFrame dapat dipecah (di-<i>slicing</i> satu kolom) membentuk sebuah Series.<br><br>

# %% [markdown]
# ### 👨‍💻 Task 3
#
# Data karyawan DQTech disajikan pada dictionary berikut
#
# ```
# details = {
#     'Name' : ['Aksara', 'Antara', 'Sendja', 'Sunyi'],
#     'Age' : [23, 21, 22, 21],
#     'Role' : ['Jr. Data Scientist', 'Data Engineer', 'Data Analyst', 'Data Scientist']
# }
# ```
#
# konversi dictionary tersebut menjadi DataFrame pandas

# %%
# Import library
import pandas as pd

# Initialize Data
details = {
    'Name' : ['Aksara', 'Antara', 'Sendja', 'Sunyi'],
    'Age'  : [23, 21, 22, 21],
    'Role' : ['Jr. Data Scientist', 'Data Engineer', 'Data Analyst', 'Data Scientist']
}

# Write your code below here & exec!
dqtech_employee = pd.DataFrame(details)

# Tampilkan data
display(dqtech_employee)
# Out:
#      Name  Age                Role
# 0  Aksara   23  Jr. Data Scientist
# 1  Antara   21       Data Engineer
# 2  Sendja   22        Data Analyst
# 3   Sunyi   21      Data Scientist

# %% [markdown]
# ## **4. Parts Of DataFrame**
#
# Untuk lebih memahami objek DataFrame, perlu diketahui bahwa DataFrame terdiri dari tiga komponen sebagai atribut berikut :
#
# <ul>1️⃣ .values : Nilai - nilai yang tertera pada DataFrame</ul>
# <ul>2️⃣ .columns : Nama kolom yang ada pada DataFrame</ul>
# <ul>3️⃣ .index : Nama atau nomor index pada DataFrame</ul>

# %% [markdown]
# ### 👨‍💻 Task 4
#
# Pada DataFrame yang telah dibuat pada Task 3, coba buatkan list nama kolomnya!

# %%
# Write your code below here & exec!
print(dqtech_employee.columns)
# Out:
# Index(['Name', 'Age', 'Role'], dtype='object')

# %%
# Write your code below here & exec!
print(dqtech_employee.values)
# Out:
# [['Aksara' 23 'Jr. Data Scientist']
#  ['Antara' 21 'Data Engineer']
#  ['Sendja' 22 'Data Analyst']
#  ['Sunyi' 21 'Data Scientist']]

# %%
# Write your code below here & exec!
print(repr(dqtech_employee.values))
# Out:
# array([['Aksara', 23, 'Jr. Data Scientist'],
#        ['Antara', 21, 'Data Engineer'],
#        ['Sendja', 22, 'Data Analyst'],
#        ['Sunyi', 21, 'Data Scientist']], dtype=object)

# %%
dqtech_employee.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# tampilkan juga nilai (data) nya!

# %%
# Write your code below here & exec!
...
# Out:
# array([['Aksara', 23, 'Jr. Data Scientist'],
#        ['Antara', 21, 'Data Engineer'],
#        ['Sendja', 22, 'Data Analyst'],
#        ['Sunyi', 21, 'Data Scientist']], dtype=object)

# %% [markdown]
# Sekalian indexnya deh wkwk 🕺

# %%
# Write your code below here & exec!
dqtech_employee.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# # **Data Manipulation**
#
# Data Manipulation adalah sebuah metode pengorganisasian data agar lebih mudah dibaca, terstruktur dan agar lebih mudah diolah untuk kebutuhan lain kedepannya. Beberapa hal yang biasa dilakukan saat data manipulation adalah sebagai berikut :
#
#
# <ul>1️⃣ Column selections</ul>
# <ul>2️⃣ Filter the data</ul>
# <ul>3️⃣ Create a new column or change it</ul>
# <ul>4️⃣ Drop a column</ul>
# <ul>5️⃣ Apply custom functions</ul>
# <ul>6️⃣ Join / Merge the data</ul>
# <ul>7️⃣ etc</ul>

# %% [markdown]
# ## **5. Data Extraction**
#
# * Dalam konteks data extraction, Pandas dapat digunakan untuk membaca data dari berbagai sumber, seperti file CSV, Excel, SQL database, dan lainnya, dan mengubahnya menjadi DataFrames untuk analisis lebih lanjut.
#
# * Beberapa fungsi dan metode Pandas yang umum digunakan untuk data extraction adalah sebagai berikut:
#
# <ul>
# <code><a href="https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html">pd.read_csv()</a></code>: Digunakan untuk membaca data dari file CSV dan mengonversinya menjadi DataFrame.
#
# <code><a href="https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html">pd.read_excel()</a></code>: Membaca data dari file Excel dan membuat DataFrame dari lembar kerja atau tabel tertentu.
#
# <code><a href="https://pandas.pydata.org/docs/reference/api/pandas.read_sql.html">pd.read_sql()</a></code>: Mengambil data dari basis data SQL menggunakan SQL query dan menyimpannya dalam bentuk DataFrame.
# </ul>

# %% [markdown]
# ### 👨‍💻 Task 5
#
# Untuk melakukan proses ekstraksi data, lakukan instruksi berikut :
#
# 1.   Lakukan proses autentikasi dengan menjalankan kode dibawah ini hingga muncul tampilan
#
# ![image.png](data:image/png;base64,...)
#
# lakukan hingga proses autentikasi berhasil

# %%
from google.colab import auth, data_table
from google.cloud import bigquery
from pandas_gbq import to_gbq

# Proses autentikasi akun
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# 2. Copy project-id lalu masukan ke variabel project_id dibawah ini
#
# ![image.png](data:image/png;base64,...)

# %%
# Buat BigQuery client
project_id = 'dqlabyumna'
client = bigquery.Client(project = project_id)

# %% [markdown]
# 3. Lakukan proses ekstraksi data dengan mengeksekusi kode berikut

# %%
# Inisialisasi query yang akan dijalankan
query = "SELECT * FROM dqlab-468906.pilotclass.tbl_superstore"

# Proses ekstraksi data dari BigQuery ke pandas
data_superstore = client.query(query).to_dataframe()

# Tampilkan hasil
data_superstore.sample(10)
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 5360    1948  CA-2017-157987  02/09/2017    6092017  Standard Class
# 8789    9806  CA-2016-136322  21/10/2016   26102016  Standard Class
# 1988    9274  CA-2017-146983  02/09/2017    6092017  Standard Class
# 5299    8389  CA-2014-139423  01/11/2014    5112014  Standard Class
# 3261    9719  CA-2016-108210  30/05/2016   31052016        Same Day
# 4151    5781  US-2015-159513  02/04/2015    9042015  Standard Class
# 269     7040  CA-2017-103443  17/12/2017   23122017  Standard Class
# 680     9441  CA-2014-100391  25/05/2014   29052014  Standard Class
# 3871    3644  CA-2014-156594  20/12/2014   23122014    Second Class
# 4426    9994  CA-2017-119914  04/05/2017    9052017    Second Class
#
#      customer_id  customer_name      segment        country             city  \
# 5360    AC-10615      Ann Chong    Corporate  United States    New York City
# 8789    AP-10720     Anne Pryor  Home Office  United States  Fort Lauderdale
# 1988    AH-10210     Alan Hwang     Consumer  United States        Henderson
# 5299    DG-13300  Deirdre Greer    Corporate  United States           Orange
# 3261    AT-10735  Annie Thurman     Consumer  United States          Houston
# 4151    JD-15790     John Dryer     Consumer  United States      Los Angeles
# 269     AT-10735  Annie Thurman     Consumer  United States    New York City
# 680     BW-11065  Barry Weirich     Consumer  United States    New York City
# 3871    MC-17845   Michael Chen     Consumer  United States      Los Angeles
# 4426    CC-12220   Chris Cortes     Consumer  United States      Westminster
#
#       ... postal_code   region       product_id         category sub-category  \
# 5360  ...       10009     East  FUR-FU-10001196        Furniture  Furnishings
# 8789  ...       33311    South  FUR-FU-10002878        Furniture  Furnishings
# 1988  ...       42420    South  OFF-BI-10003650  Office Supplies      Binders
# 5299  ...        7050     East  OFF-AP-10004708  Office Supplies   Appliances
# 3261  ...       77041  Central  TEC-AC-10000109       Technology  Accessories
# 4151  ...       90049     West  TEC-MA-10003329       Technology     Machines
# 269   ...       10009     East  OFF-ST-10002276  Office Supplies      Storage
# 680   ...       10035     East  OFF-PA-10001471  Office Supplies        Paper
# 3871  ...       90008     West  OFF-AR-10001725  Office Supplies          Art
# 4426  ...       92683     West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name     sales  quantity  \
# 5360                          DAX Cubicle Frames - 8x10    11.540         2
# 8789                Seth Thomas 14" Day/Date Wall Clock    45.568         2
# 1988          GBC DocuBind 300 Electric Binding Machine  1577.940         3
# 5299  Fellowes Superior 10 Outlet Split Surge Protector    76.120         2
# 3261   Sony Micro Vault Click 16 GB USB 2.0 Flash Drive   223.960         5
# 4151       Vtech AT&T CL2940 Corded Speakerphone, Black    71.976         3
# 269                        Safco Steel Mobile File Cart   166.720         2
# 680                        Strathmore Photo Frame Cards    14.620         2
# 3871  Boston Home & Office Model 2000 Electric Penci...    47.300         2
# 4426  Acco 7-Outlet Masterpiece Power Center, Wihtou...   243.160         2
#
#       discount    profit
# 5360       0.0    3.4620
# 8789       0.2    9.6832
# 1988       0.0  757.4112
# 5299       0.0   22.0748
# 3261       0.2   11.1980
# 4151       0.2   24.2919
# 269        0.0   41.6800
# 680        0.0    6.7252
# 3871       0.0   12.2980
# 4426       0.0   72.9480
#
# [10 rows x 21 columns]

# %% [markdown]
# ## **6. Inspecting Data Information**
#
# * Untuk dapat menginspeksi informasi umum pada data dapat menggunakan sintaks berikut
#
# <p align="center"><code><b>DataFrame.info()</b></code></p>
#
# <ul>Ketika dijalankan, sintaks tersebut akan menghasilkan output informasi umum pada data seperti banyak kolom, nama kolom beserta tipe data dan jumlah data tak kosong (<i>non-null value</i>)</ul><br>
#
# <p align="right"><sup>docs : <i><a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html">https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html</i></sup></a></p>

# %% [markdown]
# ### 👨‍💻 Task 6
#
# Inspeksi informasi umum pada data yang telah diekstraksi dan telah disimpan pada variabel <code>data_superstore</code>. Setelah itu coba uraikan informasi apa yang bisa anda dapatkan setelah melakukan inspeksi informasi umum pada <code>data_superstore</code>?

# %%
# Write your code below here & exec!
data_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   Int64
#  1   order_id       9994 non-null   object
#  2   order_date     9994 non-null   object
#  3   ship_date      9994 non-null   Int64
#  4   ship_mode      9994 non-null   object
#  5   customer_id    9994 non-null   object
#  6   customer_name  9994 non-null   object
#  7   segment        9994 non-null   object
#  8   country        9994 non-null   object
#  9   city           9994 non-null   object
#  10  state          9994 non-null   object
#  11  postal_code    9994 non-null   Int64
#  12  region         9994 non-null   object
#  13  product_id     9994 non-null   object
#  14  category       9994 non-null   object
#  15  sub-category   9994 non-null   object
#  16  product_name   9994 non-null   object
#  17  sales          9994 non-null   float64
#  18  quantity       9994 non-null   Int64
#  19  discount       9994 non-null   float64
#  20  profit         9994 non-null   float64
# dtypes: Int64(4), float64(3), object(14)
# memory usage: 1.6+ MB

# %%
type(data_superstore)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **7. Data Selection**
#
# * Untuk memilih kolom tertentu pada sebuah DataFrame dapat menggunakan sintaks berikut
#
# <p align="center"><code><b>DataFrame.loc[baris , nama_kolom]</b></code></p>
#
# * <code>baris</code>
# <ul>
#   <li>Gunakan simbol ( : ) untuk menampilkan semua data</li>
#   <li>Gunakan simbol (m : n) untuk menampilkan data dari index ke - m sampai dengan index ke - n</li>
# </ul>
#
# * <code>nama_kolom</code>
# <ul>
#   <li>Gunakan string untuk mengakses satu kolom saja (<i>return : Series</i>)</li>
#   <li>Gunakan list untuk mengakses lebih dari satu kolom  (<i>return : DataFrame</i>)</li>
# </ul>

# %% [markdown]
# ### 👨‍💻 Task 7 - A
#
# Pada DataFrame <code>data_superstore</code>, simpan 10 data teratas ke dalam variabel **order_id** untuk kolom **Order_ID** saja. Kemudian tampilkan data tersebut!

# %%
# Write your code below here & exec!
order_id = data_superstore.loc[0:9, 'order_id']

# Tampilkan hasilnya
display(order_id)
# Out:
# 0    CA-2015-154900
# 1    CA-2015-154900
# 2    US-2016-152415
# 3    US-2016-152415
# 4    CA-2016-153269
# 5    CA-2016-153269
# 6    CA-2016-153269
# 7    CA-2016-153269
# 8    CA-2015-158792
# 9    CA-2016-141082
# Name: order_id, dtype: object

# %% [markdown]
# ### 👨‍💻 Task 7 - B
#
# Pada DataFrame <code>data_superstore</code>, tampilkan data dengan index ke-2 sampai dengan index ke-5 kolom **Order_ID**, **Sales**, **Profit** saja

# %%
# Write your code below here & exec!
col_selection = ['order_id', 'sales', 'profit']
data_sales = data_superstore.loc[2:5, col_selection]

# Tqampilkan hasilnya
display(data_sales)
# Out:
#          order_id   sales   profit
# 2  US-2016-152415   14.82   6.2244
# 3  US-2016-152415  191.82  61.3824
# 4  CA-2016-153269   11.21   3.3630
# 5  CA-2016-153269  354.90  88.7250

# %% [markdown]
# atau secara sederhana anda dapat menggunakan `DataFrame[nama_kolom]` untuk menghasilkan sebuah Series satu kolom dan `DataFrame[[nama_kolom1, nama_kolom2, ...]]` untuk menseleksi banyak kolom kedalam bentuk DataFrame

# %% [markdown]
# ### 👨‍💻 Task 7 - C
#
# Pada DataFrame <code>data_superstore</code>, simpan ke dalam variabel **order_id** untuk kolom **Order_ID** saja (gunakan seleksi sederhana). Kemudian tampilkan data tersebut!

# %%
# Write your code below here & exec!
order_id = data_superstore.loc[:, 'order_id']

display(order_id)
# Out:
# 0       CA-2015-154900
# 1       CA-2015-154900
# 2       US-2016-152415
# 3       US-2016-152415
# 4       CA-2016-153269
#              ...
# 9989    US-2016-158680
# 9990    CA-2015-150511
# 9991    US-2014-131982
# 9992    CA-2016-155488
# 9993    CA-2017-145506
# Name: order_id, Length: 9994, dtype: object

# %%
order_id = data_superstore['order_id']
order_id = data_superstore.loc[:, 'order_id']

# %% [markdown]
# ##**8. Conditions**
#
# * Salah satu teknik paling sederhana untuk menemukan bagian mana dari kumpulan data yang menarik adalah menemukan subset baris yang cocok dengan beberapa kriteria untuk difilter atau dipilih. Untuk melakukan hal ini cukup mudah yakni dengan menuliskan kondisi seperti berikut
#
# <p align="center"><code><b>DataFrame.loc[conditions]</b></code></p>
#
# * Conditions dapat dibentuk dari 1 atau lebih kriteria boolean dan dihubungkan dengan operator logika and (&), or (|) atau not (~)
#
# <br>
#
# docs : <i>https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html</i>

# %% [markdown]
# ### 👨‍💻 Task 8 - A
#
# Pada DataFrame `data_superstore` tampilkan semua record data yang terjadi di 'Los Angeles' saja

# %%
# Write your code below here & exec!

# Assign conditions
conditions = (data_superstore['city'] == 'Los Angeles')

# Filter
data_LA = data_superstore.loc[conditions]

# Tampilkeun
display(data_LA)
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 3801      63  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3802      64  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3803      65  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3804      66  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3805     172  CA-2014-118962  05/08/2014    9082014  Standard Class
# ...      ...             ...         ...        ...             ...
# 9663    8174  CA-2014-114125  09/07/2014   13072014  Standard Class
# 9664    8175  CA-2014-114125  09/07/2014   13072014  Standard Class
# 9665    8504  CA-2014-164903  20/02/2014   24022014  Standard Class
# 9666    9141  CA-2017-123029  30/09/2017    2102017    Second Class
# 9667    9229  CA-2014-153619  03/11/2014    3112014        Same Day
#
#      customer_id    customer_name      segment        country         city  \
# 3801    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3802    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3803    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3804    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3805    CS-12130     Chad Sievert     Consumer  United States  Los Angeles
# ...          ...              ...          ...            ...          ...
# 9663    GH-14410      Gary Hansen  Home Office  United States  Los Angeles
# 9664    GH-14410      Gary Hansen  Home Office  United States  Los Angeles
# 9665    SR-20740    Steven Roelle  Home Office  United States  Los Angeles
# 9666    BT-11530  Bradley Talbott  Home Office  United States  Los Angeles
# 9667    TC-21535    Tracy Collins  Home Office  United States  Los Angeles
#
#       ... postal_code  region       product_id         category sub-category  \
# 3801  ...       90004    West  TEC-AC-10004633       Technology  Accessories
# 3802  ...       90004    West  OFF-BI-10001078  Office Supplies      Binders
# 3803  ...       90004    West  OFF-PA-10003892  Office Supplies        Paper
# 3804  ...       90004    West  FUR-FU-10000397        Furniture  Furnishings
# 3805  ...       90004    West  OFF-PA-10000659  Office Supplies        Paper
# ...   ...         ...     ...              ...              ...          ...
# 9663  ...       90049    West  OFF-BI-10003291  Office Supplies      Binders
# 9664  ...       90049    West  OFF-ST-10001505  Office Supplies      Storage
# 9665  ...       90049    West  OFF-PA-10003363  Office Supplies        Paper
# 9666  ...       90049    West  TEC-AC-10002402       Technology  Accessories
# 9667  ...       90049    West  OFF-AR-10001868  Office Supplies          Art
#
#                                            product_name    sales  quantity  \
# 3801  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...   13.980         2
# 3802  Acco PRESSTEX Data Binder with Storage Hooks, ...   25.824         6
# 3803                                         Xerox 1943  146.730         3
# 3804                        Luxo Economy Swing Arm Lamp   79.760         4
# 3805  Adams Phone Message Book, Professional, 400 Me...   20.940         3
# ...                                                 ...      ...       ...
# 9663  Wilson Jones Leather-Like Binders with DublLoc...   41.904         6
# 9664  Perma STOR-ALL Hanging File Box, 13 1/8"W x 12...   23.920         4
# 9665                                          Xerox 204   12.960         2
# 9666     Razer Kraken PRO Over Ear PC and Music Headset  159.980         2
# 9667                        Prang Dustless Chalk Sticks    6.720         4
#
#       discount   profit
# 3801       0.0   6.1512
# 3802       0.2   9.3612
# 3803       0.0  68.9631
# 3804       0.0  22.3328
# 3805       0.0   9.8418
# ...        ...      ...
# 9663       0.2  14.1426
# 9664       0.0   4.0664
# 9665       0.0   6.2208
# 9666       0.0  47.9940
# 9667       0.0   3.3600
#
# [747 rows x 21 columns]

# %%
# Write your code below here & exec!

# Assign conditions
conditions = (data_superstore['city'] == 'Los Angeles')

# Filter
data_LA = data_superstore[conditions]

# Tampilkeun
display(data_LA)
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 3801      63  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3802      64  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3803      65  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3804      66  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3805     172  CA-2014-118962  05/08/2014    9082014  Standard Class
# ...      ...             ...         ...        ...             ...
# 9663    8174  CA-2014-114125  09/07/2014   13072014  Standard Class
# 9664    8175  CA-2014-114125  09/07/2014   13072014  Standard Class
# 9665    8504  CA-2014-164903  20/02/2014   24022014  Standard Class
# 9666    9141  CA-2017-123029  30/09/2017    2102017    Second Class
# 9667    9229  CA-2014-153619  03/11/2014    3112014        Same Day
#
#      customer_id    customer_name      segment        country         city  \
# 3801    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3802    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3803    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3804    KM-16720     Kunst Miller     Consumer  United States  Los Angeles
# 3805    CS-12130     Chad Sievert     Consumer  United States  Los Angeles
# ...          ...              ...          ...            ...          ...
# 9663    GH-14410      Gary Hansen  Home Office  United States  Los Angeles
# 9664    GH-14410      Gary Hansen  Home Office  United States  Los Angeles
# 9665    SR-20740    Steven Roelle  Home Office  United States  Los Angeles
# 9666    BT-11530  Bradley Talbott  Home Office  United States  Los Angeles
# 9667    TC-21535    Tracy Collins  Home Office  United States  Los Angeles
#
#       ... postal_code  region       product_id         category sub-category  \
# 3801  ...       90004    West  TEC-AC-10004633       Technology  Accessories
# 3802  ...       90004    West  OFF-BI-10001078  Office Supplies      Binders
# 3803  ...       90004    West  OFF-PA-10003892  Office Supplies        Paper
# 3804  ...       90004    West  FUR-FU-10000397        Furniture  Furnishings
# 3805  ...       90004    West  OFF-PA-10000659  Office Supplies        Paper
# ...   ...         ...     ...              ...              ...          ...
# 9663  ...       90049    West  OFF-BI-10003291  Office Supplies      Binders
# 9664  ...       90049    West  OFF-ST-10001505  Office Supplies      Storage
# 9665  ...       90049    West  OFF-PA-10003363  Office Supplies        Paper
# 9666  ...       90049    West  TEC-AC-10002402       Technology  Accessories
# 9667  ...       90049    West  OFF-AR-10001868  Office Supplies          Art
#
#                                            product_name    sales  quantity  \
# 3801  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...   13.980         2
# 3802  Acco PRESSTEX Data Binder with Storage Hooks, ...   25.824         6
# 3803                                         Xerox 1943  146.730         3
# 3804                        Luxo Economy Swing Arm Lamp   79.760         4
# 3805  Adams Phone Message Book, Professional, 400 Me...   20.940         3
# ...                                                 ...      ...       ...
# 9663  Wilson Jones Leather-Like Binders with DublLoc...   41.904         6
# 9664  Perma STOR-ALL Hanging File Box, 13 1/8"W x 12...   23.920         4
# 9665                                          Xerox 204   12.960         2
# 9666     Razer Kraken PRO Over Ear PC and Music Headset  159.980         2
# 9667                        Prang Dustless Chalk Sticks    6.720         4
#
#       discount   profit
# 3801       0.0   6.1512
# 3802       0.2   9.3612
# 3803       0.0  68.9631
# 3804       0.0  22.3328
# 3805       0.0   9.8418
# ...        ...      ...
# 9663       0.2  14.1426
# 9664       0.0   4.0664
# 9665       0.0   6.2208
# 9666       0.0  47.9940
# 9667       0.0   3.3600
#
# [747 rows x 21 columns]

# %% [markdown]
# ### 👨‍💻 Task 8 - B
#
# Pada DataFrame `data_superstore` tampilkan semua record data yang terjadi di 'Los Angeles' untuk kategori Technology

# %%
# Write your code below here & exec!

# Assign conditions
conditions1 = (data_superstore['city'] == 'Los Angeles')
conditions2 = (data_superstore['category'] == 'Technology')

# Filter
data_LA = data_superstore.loc[conditions1][conditions2]

# Tampilkeun
display(data_LA)
# Out:
# /tmp/ipython-input-2199628630.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_LA = data_superstore.loc[conditions1][conditions2]
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 3801      63  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3816    1573  US-2014-157385  23/11/2014   25112014     First Class
# 3830    3423  CA-2016-134803  28/05/2016    3062016  Standard Class
# 3832    3425  CA-2016-134803  28/05/2016    3062016  Standard Class
# 3834    3619  CA-2017-141929  04/09/2017    8092017  Standard Class
# ...      ...             ...         ...        ...             ...
# 9649    3132  CA-2014-136399  16/12/2014   17122014     First Class
# 9650    4338  CA-2015-125234  27/11/2015    1122015  Standard Class
# 9652    4620  CA-2017-145219  24/12/2017   25122017     First Class
# 9660    7816  US-2017-109316  08/06/2017   10062017     First Class
# 9666    9141  CA-2017-123029  30/09/2017    2102017    Second Class
#
#      customer_id      customer_name      segment        country         city  \
# 3801    KM-16720       Kunst Miller     Consumer  United States  Los Angeles
# 3816    SC-20095       Sanjit Chand     Consumer  United States  Los Angeles
# 3830    CL-12565        Clay Ludtke     Consumer  United States  Los Angeles
# 3832    CL-12565        Clay Ludtke     Consumer  United States  Los Angeles
# 3834    RA-19285       Ralph Arnett     Consumer  United States  Los Angeles
# ...          ...                ...          ...            ...          ...
# 9649    CC-12100    Chad Cunningham  Home Office  United States  Los Angeles
# 9650    SN-20710       Steve Nguyen  Home Office  United States  Los Angeles
# 9652    RM-19675      Robert Marley  Home Office  United States  Los Angeles
# 9660    MG-17680  Maureen Gastineau  Home Office  United States  Los Angeles
# 9666    BT-11530    Bradley Talbott  Home Office  United States  Los Angeles
#
#       ... postal_code  region       product_id    category sub-category  \
# 3801  ...       90004    West  TEC-AC-10004633  Technology  Accessories
# 3816  ...       90004    West  TEC-AC-10003280  Technology  Accessories
# 3830  ...       90004    West  TEC-AC-10002217  Technology  Accessories
# 3832  ...       90004    West  TEC-MA-10001972  Technology     Machines
# 3834  ...       90004    West  TEC-PH-10002185  Technology       Phones
# ...   ...         ...     ...              ...         ...          ...
# 9649  ...       90049    West  TEC-PH-10004977  Technology       Phones
# 9650  ...       90049    West  TEC-AC-10000158  Technology  Accessories
# 9652  ...       90049    West  TEC-CO-10001449  Technology      Copiers
# 9660  ...       90049    West  TEC-PH-10000307  Technology       Phones
# 9666  ...       90049    West  TEC-AC-10002402  Technology  Accessories
#
#                                            product_name     sales  quantity  \
# 3801  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...    13.980         2
# 3816         Belkin F8E887 USB Wired Ergonomic Keyboard    29.990         1
# 3830                Imation Clip USB flash drive - 8 GB   131.600         7
# 3832                             Okidata C331dn Printer   558.400         2
# 3834  QVS USB Car Charger 2-Port 2.1Amp for iPod/iPh...     5.560         1
# ...                                                 ...       ...       ...
# 9649                                        GE 30524EE4   627.168         4
# 9650      Sony 64GB Class 10 Micro SDHC R40 Memory Card   107.970         3
# 9652               Hewlett Packard LaserJet 3310 Copier  2879.952         6
# 9660                        Shocksock Galaxy S4 Armband    17.520         2
# 9666     Razer Kraken PRO Over Ear PC and Music Headset   159.980         2
#
#       discount     profit
# 3801       0.0     6.1512
# 3816       0.0     6.2979
# 3830       0.0     7.8960
# 3832       0.2    41.8800
# 3834       0.2     1.7375
# ...        ...        ...
# 9649       0.2    70.5564
# 9650       0.0    22.6737
# 9652       0.2  1007.9832
# 9660       0.2    -3.5040
# 9666       0.0    47.9940
#
# [150 rows x 21 columns]

# %%
type(data_superstore)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_superstore[conditions1])
# Out:
# pandas.core.frame.DataFrame

# %%
# Write your code below here & exec!

# Assign conditions
conditions1 = (data_superstore['city'] == 'Los Angeles')
conditions2 = (data_superstore['category'] == 'Technology')

# Filter
data_LA = data_superstore.loc[conditions1 & conditions2]

# Tampilkeun
display(data_LA)
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 3801      63  CA-2015-135545  24/11/2015   30112015  Standard Class
# 3816    1573  US-2014-157385  23/11/2014   25112014     First Class
# 3830    3423  CA-2016-134803  28/05/2016    3062016  Standard Class
# 3832    3425  CA-2016-134803  28/05/2016    3062016  Standard Class
# 3834    3619  CA-2017-141929  04/09/2017    8092017  Standard Class
# ...      ...             ...         ...        ...             ...
# 9649    3132  CA-2014-136399  16/12/2014   17122014     First Class
# 9650    4338  CA-2015-125234  27/11/2015    1122015  Standard Class
# 9652    4620  CA-2017-145219  24/12/2017   25122017     First Class
# 9660    7816  US-2017-109316  08/06/2017   10062017     First Class
# 9666    9141  CA-2017-123029  30/09/2017    2102017    Second Class
#
#      customer_id      customer_name      segment        country         city  \
# 3801    KM-16720       Kunst Miller     Consumer  United States  Los Angeles
# 3816    SC-20095       Sanjit Chand     Consumer  United States  Los Angeles
# 3830    CL-12565        Clay Ludtke     Consumer  United States  Los Angeles
# 3832    CL-12565        Clay Ludtke     Consumer  United States  Los Angeles
# 3834    RA-19285       Ralph Arnett     Consumer  United States  Los Angeles
# ...          ...                ...          ...            ...          ...
# 9649    CC-12100    Chad Cunningham  Home Office  United States  Los Angeles
# 9650    SN-20710       Steve Nguyen  Home Office  United States  Los Angeles
# 9652    RM-19675      Robert Marley  Home Office  United States  Los Angeles
# 9660    MG-17680  Maureen Gastineau  Home Office  United States  Los Angeles
# 9666    BT-11530    Bradley Talbott  Home Office  United States  Los Angeles
#
#       ... postal_code  region       product_id    category sub-category  \
# 3801  ...       90004    West  TEC-AC-10004633  Technology  Accessories
# 3816  ...       90004    West  TEC-AC-10003280  Technology  Accessories
# 3830  ...       90004    West  TEC-AC-10002217  Technology  Accessories
# 3832  ...       90004    West  TEC-MA-10001972  Technology     Machines
# 3834  ...       90004    West  TEC-PH-10002185  Technology       Phones
# ...   ...         ...     ...              ...         ...          ...
# 9649  ...       90049    West  TEC-PH-10004977  Technology       Phones
# 9650  ...       90049    West  TEC-AC-10000158  Technology  Accessories
# 9652  ...       90049    West  TEC-CO-10001449  Technology      Copiers
# 9660  ...       90049    West  TEC-PH-10000307  Technology       Phones
# 9666  ...       90049    West  TEC-AC-10002402  Technology  Accessories
#
#                                            product_name     sales  quantity  \
# 3801  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...    13.980         2
# 3816         Belkin F8E887 USB Wired Ergonomic Keyboard    29.990         1
# 3830                Imation Clip USB flash drive - 8 GB   131.600         7
# 3832                             Okidata C331dn Printer   558.400         2
# 3834  QVS USB Car Charger 2-Port 2.1Amp for iPod/iPh...     5.560         1
# ...                                                 ...       ...       ...
# 9649                                        GE 30524EE4   627.168         4
# 9650      Sony 64GB Class 10 Micro SDHC R40 Memory Card   107.970         3
# 9652               Hewlett Packard LaserJet 3310 Copier  2879.952         6
# 9660                        Shocksock Galaxy S4 Armband    17.520         2
# 9666     Razer Kraken PRO Over Ear PC and Music Headset   159.980         2
#
#       discount     profit
# 3801       0.0     6.1512
# 3816       0.0     6.2979
# 3830       0.0     7.8960
# 3832       0.2    41.8800
# 3834       0.2     1.7375
# ...        ...        ...
# 9649       0.2    70.5564
# 9650       0.0    22.6737
# 9652       0.2  1007.9832
# 9660       0.2    -3.5040
# 9666       0.0    47.9940
#
# [150 rows x 21 columns]

# %% [markdown]
# ### 👨‍💻 Task 8 - C
#
# Pada DataFrame `data_superstore` tampilkan record data yang terjadi di 'Los Angeles' untuk kategori Technology. Namun hanya tampilkan kolom 'Order_ID', 'City', 'Category' dan 'Profit'

# %%
# Assign conditions
conditions1 = (data_superstore ['city'] == 'Los Angeles')
conditions2 = (data_superstore ['category'] == 'Technology')
list_shown = ['order_id', 'city', 'category', 'profit']

# Filter
data_LA_tech = data_superstore[list_shown][conditions1 & conditions2]

# Tampilkeun
display(data_LA_tech)
# Out:
#             order_id         city    category     profit
# 3801  CA-2015-135545  Los Angeles  Technology     6.1512
# 3816  US-2014-157385  Los Angeles  Technology     6.2979
# 3830  CA-2016-134803  Los Angeles  Technology     7.8960
# 3832  CA-2016-134803  Los Angeles  Technology    41.8800
# 3834  CA-2017-141929  Los Angeles  Technology     1.7375
# ...              ...          ...         ...        ...
# 9649  CA-2014-136399  Los Angeles  Technology    70.5564
# 9650  CA-2015-125234  Los Angeles  Technology    22.6737
# 9652  CA-2017-145219  Los Angeles  Technology  1007.9832
# 9660  US-2017-109316  Los Angeles  Technology    -3.5040
# 9666  CA-2017-123029  Los Angeles  Technology    47.9940
#
# [150 rows x 4 columns]

# %%
data_LA_tech = data_superstore.loc[conditions1 & conditions2, list_shown]
data_LA_tech
# Out:
#             order_id         city    category     profit
# 3801  CA-2015-135545  Los Angeles  Technology     6.1512
# 3816  US-2014-157385  Los Angeles  Technology     6.2979
# 3830  CA-2016-134803  Los Angeles  Technology     7.8960
# 3832  CA-2016-134803  Los Angeles  Technology    41.8800
# 3834  CA-2017-141929  Los Angeles  Technology     1.7375
# ...              ...          ...         ...        ...
# 9649  CA-2014-136399  Los Angeles  Technology    70.5564
# 9650  CA-2015-125234  Los Angeles  Technology    22.6737
# 9652  CA-2017-145219  Los Angeles  Technology  1007.9832
# 9660  US-2017-109316  Los Angeles  Technology    -3.5040
# 9666  CA-2017-123029  Los Angeles  Technology    47.9940
#
# [150 rows x 4 columns]

# %% [markdown]
# ## **9. Sorting Row**
#
# Menemukan data yang menarik dalam sebuah DataFrame seringkali lebih mudah jika dilakukan pengurutan baris datanya. Pengurutan dibagi menjadi dua yakni pengurutan secara `Ascending` (pengurutan naik A → Z) dan juga pengurutan secara `Descending` (pengurutan turun Z → A). Eksekusi sintaks berikut :
#
# <p align="center"><code><b>DataFrame.sort_values(by, ascending=True, ignore_index=False)</b></code></p>
#
# Jika ingin mengurutkan DataFrame pandas dengan memperhatikan argumen
#
# <ul>
# <li><b><i>by</i></b> sebagai satu atau lebih kolom yang ingin dijadikan patokan pengurutan</li>
#
# <li><b><i>ascending</i></b> dapat diisikan True jika ingin terurut naik atau False jika ingin terurut turun (dafault : True)</li>
#
# <li><b><i>ignore_index</i></b> dapat diisikan True jika ingin index masih terurut atau False jika indexnya masih dipertahankan sesuai data awal (dafault : False)</li>
#
# </ul><br>
#
# docs : <i>https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html</i>

# %% [markdown]
# ### 👨‍💻 Task 9 - A
#
# Pada DataFrame `data_superstore`, tampilkan semua record data namun urutkan secara ascending pada kolom Order_ID

# %%
# Write your code below here & exec!
data_superstore.sort_values(by = ['order_id'], ascending = True)
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 449     2718  CA-2014-100006  07/09/2014   13092014  Standard Class
# 7960    6288  CA-2014-100090  08/07/2014   12072014  Standard Class
# 7961    6289  CA-2014-100090  08/07/2014   12072014  Standard Class
# 8754    9515  CA-2014-100293  14/03/2014   18032014  Standard Class
# 450     3084  CA-2014-100328  28/01/2014    3022014  Standard Class
# ...      ...             ...         ...        ...             ...
# 873     5934  US-2017-169551  07/07/2017    9072017     First Class
# 872     5933  US-2017-169551  07/07/2017    9072017     First Class
# 871     5932  US-2017-169551  07/07/2017    9072017     First Class
# 869     5930  US-2017-169551  07/07/2017    9072017     First Class
# 870     5931  US-2017-169551  07/07/2017    9072017     First Class
#
#      customer_id     customer_name      segment        country           city  \
# 449     DK-13375       Dennis Kane     Consumer  United States  New York City
# 7960    EB-13705        Ed Braxton    Corporate  United States  San Francisco
# 7961    EB-13705        Ed Braxton    Corporate  United States  San Francisco
# 8754    NF-18475  Neil Französisch  Home Office  United States   Jacksonville
# 450     JC-15340   Jasper Cacioppo     Consumer  United States  New York City
# ...          ...               ...          ...            ...            ...
# 873     RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 872     RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 871     RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 869     RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 870     RL-19615         Rob Lucas     Consumer  United States   Philadelphia
#
#       ... postal_code  region       product_id         category sub-category  \
# 449   ...       10024    East  TEC-PH-10002075       Technology       Phones
# 7960  ...       94122    West  FUR-TA-10003715        Furniture       Tables
# 7961  ...       94122    West  OFF-BI-10001597  Office Supplies      Binders
# 8754  ...       32216   South  OFF-PA-10000176  Office Supplies        Paper
# 450   ...       10024    East  OFF-BI-10000343  Office Supplies      Binders
# ...   ...         ...     ...              ...              ...          ...
# 873   ...       19120    East  TEC-AC-10002018       Technology  Accessories
# 872   ...       19120    East  OFF-ST-10004835  Office Supplies      Storage
# 871   ...       19120    East  TEC-PH-10001363       Technology       Phones
# 869   ...       19120    East  FUR-BO-10001519        Furniture    Bookcases
# 870   ...       19120    East  OFF-PA-10004100  Office Supplies        Paper
#
#                                            product_name    sales  quantity  \
# 449                                   AT&T EL51110 DECT  377.970         3
# 7960            Hon 2111 Invitation Series Corner Table  502.488         3
# 7961  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...  196.704         6
# 8754                                         Xerox 1887   91.056         6
# 450   Pressboard Covers with Storage Hooks, 9 1/2" x...    3.928         1
# ...                                                 ...      ...       ...
# 873               AmazonBasics 3-Button USB Wired Mouse   16.776         3
# 872                   Plastic Stacking Crates & Casters   13.392         3
# 871                                     Apple iPhone 5S  683.988         2
# 869             O'Sullivan 3-Shelf Heavy-Duty Bookcases   87.210         3
# 870                                           Xerox 216   15.552         3
#
#       discount    profit
# 449        0.0  109.6113
# 7960       0.2  -87.9354
# 7961       0.2   68.8464
# 8754       0.2   31.8696
# 450        0.2    1.3257
# ...        ...       ...
# 873        0.2    4.8231
# 872        0.2    1.0044
# 871        0.4 -113.9980
# 869        0.5  -45.3492
# 870        0.2    5.4432
#
# [9994 rows x 21 columns]

# %%
data_superstore.head()
# Out:
#    row_id        order_id  order_date  ship_date       ship_mode customer_id  \
# 0    5769  CA-2015-154900  25/02/2015    1032015  Standard Class    SS-20875
# 1    5770  CA-2015-154900  25/02/2015    1032015  Standard Class    SS-20875
# 2    9028  US-2016-152415  17/09/2016   22092016  Standard Class    PO-18865
# 3    9029  US-2016-152415  17/09/2016   22092016  Standard Class    PO-18865
# 4    8332  CA-2016-153269  09/03/2016   12032016     First Class    PS-18760
#
#        customer_name   segment        country         city  ... postal_code  \
# 0      Sung Shariari  Consumer  United States   Leominster  ...        1453
# 1      Sung Shariari  Consumer  United States   Leominster  ...        1453
# 2  Patrick O'Donnell  Consumer  United States  Marlborough  ...        1752
# 3  Patrick O'Donnell  Consumer  United States  Marlborough  ...        1752
# 4       Pamela Stobb  Consumer  United States      Andover  ...        1810
#
#    region       product_id         category sub-category  \
# 0    East  OFF-LA-10001641  Office Supplies       Labels
# 1    East  OFF-PA-10002377  Office Supplies        Paper
# 2    East  FUR-FU-10002597        Furniture  Furnishings
# 3    East  FUR-FU-10004864        Furniture  Furnishings
# 4    East  OFF-ST-10004634  Office Supplies      Storage
#
#                                         product_name   sales  quantity  \
# 0                                          Avery 518    3.15         1
# 1  Adams Telephone Message Book W/Dividers/Space ...   22.72         4
# 2  C-Line Magnetic Cubicle Keepers, Clear Polypro...   14.82         3
# 3  Howard Miller 14-1/2" Diameter Chrome Round Wa...  191.82         3
# 4                      Personal Folder Holder, Ebony   11.21         1
#
#    discount   profit
# 0       0.0   1.5120
# 1       0.0  10.2240
# 2       0.0   6.2244
# 3       0.0  61.3824
# 4       0.0   3.3630
#
# [5 rows x 21 columns]

# %%
# Write your code below here & exec!
data_superstore.sort_values(by = ['order_id'], ascending = True, ignore_index = True )
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 0       2718  CA-2014-100006  07/09/2014   13092014  Standard Class
# 1       6288  CA-2014-100090  08/07/2014   12072014  Standard Class
# 2       6289  CA-2014-100090  08/07/2014   12072014  Standard Class
# 3       9515  CA-2014-100293  14/03/2014   18032014  Standard Class
# 4       3084  CA-2014-100328  28/01/2014    3022014  Standard Class
# ...      ...             ...         ...        ...             ...
# 9989    5934  US-2017-169551  07/07/2017    9072017     First Class
# 9990    5933  US-2017-169551  07/07/2017    9072017     First Class
# 9991    5932  US-2017-169551  07/07/2017    9072017     First Class
# 9992    5930  US-2017-169551  07/07/2017    9072017     First Class
# 9993    5931  US-2017-169551  07/07/2017    9072017     First Class
#
#      customer_id     customer_name      segment        country           city  \
# 0       DK-13375       Dennis Kane     Consumer  United States  New York City
# 1       EB-13705        Ed Braxton    Corporate  United States  San Francisco
# 2       EB-13705        Ed Braxton    Corporate  United States  San Francisco
# 3       NF-18475  Neil Französisch  Home Office  United States   Jacksonville
# 4       JC-15340   Jasper Cacioppo     Consumer  United States  New York City
# ...          ...               ...          ...            ...            ...
# 9989    RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 9990    RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 9991    RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 9992    RL-19615         Rob Lucas     Consumer  United States   Philadelphia
# 9993    RL-19615         Rob Lucas     Consumer  United States   Philadelphia
#
#       ... postal_code  region       product_id         category sub-category  \
# 0     ...       10024    East  TEC-PH-10002075       Technology       Phones
# 1     ...       94122    West  FUR-TA-10003715        Furniture       Tables
# 2     ...       94122    West  OFF-BI-10001597  Office Supplies      Binders
# 3     ...       32216   South  OFF-PA-10000176  Office Supplies        Paper
# 4     ...       10024    East  OFF-BI-10000343  Office Supplies      Binders
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       19120    East  TEC-AC-10002018       Technology  Accessories
# 9990  ...       19120    East  OFF-ST-10004835  Office Supplies      Storage
# 9991  ...       19120    East  TEC-PH-10001363       Technology       Phones
# 9992  ...       19120    East  FUR-BO-10001519        Furniture    Bookcases
# 9993  ...       19120    East  OFF-PA-10004100  Office Supplies        Paper
#
#                                            product_name    sales  quantity  \
# 0                                     AT&T EL51110 DECT  377.970         3
# 1               Hon 2111 Invitation Series Corner Table  502.488         3
# 2     Wilson Jones Ledger-Size, Piano-Hinge Binder, ...  196.704         6
# 3                                            Xerox 1887   91.056         6
# 4     Pressboard Covers with Storage Hooks, 9 1/2" x...    3.928         1
# ...                                                 ...      ...       ...
# 9989              AmazonBasics 3-Button USB Wired Mouse   16.776         3
# 9990                  Plastic Stacking Crates & Casters   13.392         3
# 9991                                    Apple iPhone 5S  683.988         2
# 9992            O'Sullivan 3-Shelf Heavy-Duty Bookcases   87.210         3
# 9993                                          Xerox 216   15.552         3
#
#       discount    profit
# 0          0.0  109.6113
# 1          0.2  -87.9354
# 2          0.2   68.8464
# 3          0.2   31.8696
# 4          0.2    1.3257
# ...        ...       ...
# 9989       0.2    4.8231
# 9990       0.2    1.0044
# 9991       0.4 -113.9980
# 9992       0.5  -45.3492
# 9993       0.2    5.4432
#
# [9994 rows x 21 columns]

# %% [markdown]
# ### 👨‍💻 Task 9 - B
#
# Pada DataFrame `data_superstore`, tampilkan semua record data namun urutkan secara descending pada kolom Profit dan urutkan secara ascending pada kolom Quantity

# %%
# Write your code below here & exec!
data_superstore.sort_values(by = ['profit', 'quantity'], ascending = [False, True], ignore_index = True)
# Out:
#       row_id        order_id  order_date  ship_date       ship_mode  \
# 0       6827  CA-2016-118689  02/10/2016    9102016  Standard Class
# 1       8154  CA-2017-140151  23/03/2017   25032017     First Class
# 2       4191  CA-2017-166709  17/11/2017   22112017  Standard Class
# 3       9040  CA-2016-117121  17/12/2016   21122016  Standard Class
# 4       4099  CA-2014-116904  23/09/2014   28092014  Standard Class
# ...      ...             ...         ...        ...             ...
# 9989    4992  US-2017-122714  07/12/2017   13122017  Standard Class
# 9990    3012  CA-2017-134845  17/04/2017   23042017  Standard Class
# 9991    9775  CA-2014-169019  26/07/2014   30072014  Standard Class
# 9992     684  US-2017-168116  04/11/2017    4112017        Same Day
# 9993    7773  CA-2016-108196  25/11/2016    2122016  Standard Class
#
#      customer_id   customer_name      segment        country         city  \
# 0       TC-20980    Tamara Chand    Corporate  United States    Lafayette
# 1       RB-19360    Raymond Buch     Consumer  United States      Seattle
# 2       HL-15040    Hunter Lopez     Consumer  United States       Newark
# 3       AB-10105   Adrian Barton     Consumer  United States      Detroit
# 4       SC-20095    Sanjit Chand     Consumer  United States  Minneapolis
# ...          ...             ...          ...            ...          ...
# 9989    HG-14965   Henry Goldwyn    Corporate  United States      Chicago
# 9990    SR-20425  Sharelle Roach  Home Office  United States   Louisville
# 9991    LF-17185     Luke Foster     Consumer  United States  San Antonio
# 9992    GT-14635  Grant Thornton    Corporate  United States   Burlington
# 9993    CS-12505   Cindy Stewart     Consumer  United States    Lancaster
#
#       ... postal_code   region       product_id         category sub-category  \
# 0     ...       47905  Central  TEC-CO-10004722       Technology      Copiers
# 1     ...       98115     West  TEC-CO-10004722       Technology      Copiers
# 2     ...       19711     East  TEC-CO-10004722       Technology      Copiers
# 3     ...       48205  Central  OFF-BI-10000545  Office Supplies      Binders
# 4     ...       55407  Central  OFF-BI-10001120  Office Supplies      Binders
# ...   ...         ...      ...              ...              ...          ...
# 9989  ...       60653  Central  OFF-BI-10001120  Office Supplies      Binders
# 9990  ...       80027     West  TEC-MA-10000822       Technology     Machines
# 9991  ...       78207  Central  OFF-BI-10004995  Office Supplies      Binders
# 9992  ...       27217    South  TEC-MA-10004125       Technology     Machines
# 9993  ...       43130     East  TEC-MA-10000418       Technology     Machines
#
#                                           product_name      sales  quantity  \
# 0                Canon imageCLASS 2200 Advanced Copier  17499.950         5
# 1                Canon imageCLASS 2200 Advanced Copier  13999.960         4
# 2                Canon imageCLASS 2200 Advanced Copier  10499.970         3
# 3     GBC Ibimaster 500 Manual ProClick Binding System   9892.740        13
# 4                 Ibico EPK-21 Electric Binding System   9449.950         5
# ...                                                ...        ...       ...
# 9989              Ibico EPK-21 Electric Binding System   1889.990         5
# 9990         Lexmark MX611dhe Monochrome Laser Printer   2549.985         5
# 9991         GBC DocuBind P400 Electric Binding System   2177.584         8
# 9992         Cubify CubeX 3D Printer Triple Head Print   7999.980         4
# 9993         Cubify CubeX 3D Printer Double Head Print   4499.985         5
#
#       discount     profit
# 0          0.0  8399.9760
# 1          0.0  6719.9808
# 2          0.0  5039.9856
# 3          0.0  4946.3700
# 4          0.0  4630.4755
# ...        ...        ...
# 9989       0.8 -2929.4845
# 9990       0.7 -3399.9800
# 9991       0.8 -3701.8928
# 9992       0.5 -3839.9904
# 9993       0.7 -6599.9780
#
# [9994 rows x 21 columns]

# %% [markdown]
# ## **10. Summarize Data**
#
# Di pandas, method `DataFrame.describe()` digunakan untuk menghasilkan statistik deskriptif dari DataFrame. Metode ini sangat berguna untuk dengan cepat memahami statistik dasar dari data. Berikut adalah statistik utama yang disediakan :
#
# * `Jumlah` : Jumlah nilai non-null dalam setiap kolom.
# * `Rata-rata` : Rata-rata aritmetika dari setiap kolom.
# * `Standar Deviasi` : Ukuran dispersi nilai-nilai sekitar rata-rata.
# * `Minimum` : Nilai minimum dalam setiap kolom.
# * `Kuartil 25 (Q1)` : Nilai di bawahnya 25% data berada.
# * `Kuartil 50 (Median atau Q2)` : Nilai di bawahnya 50% data berada (yaitu nilai tengah).
# * `Kuartil 75 (Q3)` : Nilai di bawahnya 75% data berada.
# * `Maksimum` : Nilai maksimum dalam setiap kolom.

# %% [markdown]
# ### 👨‍💻 Task 10
#
# Pada DataFrame `data_superstore`, lakukan perhitungan statistik deskriptif pada kolom - kolom yang memiliki tipe data numerik

# %%
# Write your code below here & exec!
data_superstore.describe()
# Out:
#             row_id        ship_date   postal_code         sales  quantity  \
# count       9994.0           9994.0        9994.0   9994.000000    9994.0
# mean        4997.5  15963177.434461  55190.379428    229.858001  3.789574
# std    2885.163629   8803298.907336   32063.69335    623.245101   2.22511
# min            1.0        1012015.0        1040.0      0.444000       1.0
# 25%        2499.25        8102017.0       23223.0     17.280000       2.0
# 50%         4997.5       16082014.0       56430.5     54.490000       3.0
# 75%        7495.75       24042016.0       90008.0    209.940000       5.0
# max         9994.0       31122017.0       99301.0  22638.480000      14.0
#
#           discount       profit
# count  9994.000000  9994.000000
# mean      0.156203    28.656896
# std       0.206452   234.260108
# min       0.000000 -6599.978000
# 25%       0.000000     1.728750
# 50%       0.200000     8.666500
# 75%       0.200000    29.364000
# max       0.800000  8399.976000

# %%
# Write your code below here & exec!
data_superstore[['sales', 'quantity', 'profit']].describe()
# Out:
#               sales  quantity       profit
# count   9994.000000    9994.0  9994.000000
# mean     229.858001  3.789574    28.656896
# std      623.245101   2.22511   234.260108
# min        0.444000       1.0 -6599.978000
# 25%       17.280000       2.0     1.728750
# 50%       54.490000       3.0     8.666500
# 75%      209.940000       5.0    29.364000
# max    22638.480000      14.0  8399.976000

# %%
list_column = ['sales', 'quantity', 'profit']

data_superstore[list_column].describe()
# Out:
#               sales  quantity       profit
# count   9994.000000    9994.0  9994.000000
# mean     229.858001  3.789574    28.656896
# std      623.245101   2.22511   234.260108
# min        0.444000       1.0 -6599.978000
# 25%       17.280000       2.0     1.728750
# 50%       54.490000       3.0     8.666500
# 75%      209.940000       5.0    29.364000
# max    22638.480000      14.0  8399.976000

# %% [markdown]
# ##**11. Aggregation**
#
# Agregasi data merupakan serangkaian proses yang dilakukan untuk melakukan pengumpulan data dan dinyatakan dalam bentuk ringkasan sebagai contoh menghitung total yang dikelompokkan berdasarkan kategori tertentu, dsb.
#
# Untuk melakukan agregasi gunakan sintaks berikut
#
# <p align="center"><code><b>DataFrame.group_by(by, as_index).agg(kolom_hasil_aggregasi = (kolom_dihitung, jenis_agregasi))</b></code></p>
#
# Jenis agregasi :
# * pd.Series.sum = Menghitung total data
# * pd.Series.mean = Menghitung rataan data
# * pd.Series.max = Menghitung nilai maksimum data
# * pd.Series.min = Menghitung nilai minimum data
# * pd.Series.nunique = Menghitung jumlah data unik data
# * pd.Series.count = Menghitung banyak data

# %% [markdown]
# ### 👨‍💻 Task 11 - A
#
# Pada DataFrame `data_superstore`, Category produk apakah yang menghasilkan total profit paling tinggi? dan berapa total profit yang didapatkan?

# %%
# Write your code below here & exec!
...
# Out:
#                  total_profit_product
# Category
# Furniture                  18451.2728
# Office Supplies           122490.8008
# Technology                145454.9481

# %%
print(data_superstore.columns)
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
data_superstore.groupby('category').agg(total_profit_product=('profit', 'sum'))
# Out:
#                  total_profit_product
# category
# Furniture                  18451.2728
# Office Supplies           122490.8008
# Technology                145454.9481

# %% [markdown]
# Category product dengan profit paling tinggi adalah kategori Technology dengan profit yang dihasilkan sebesar 145454.9481

# %% [markdown]
# ### 👨‍💻 Task 11 - B
#
# Pada DataFrame `data_superstore`, lakukan perhitungan rataan Profit yang dikelompokkan berdasarkan Segment dan Category barang yang terjual

# %%
# Write your code below here & exec!
avg_profit_per_category = ...

display(avg_profit_per_category)
# Out:
#                              rataan_profit
# Segment     Category
# Consumer    Furniture             6.281293
#             Office Supplies      18.014174
#             Technology           74.445646
# Corporate   Furniture            11.741201
#             Office Supplies      22.102923
#             Technology           79.723823
# Home Office Furniture            10.705465
#             Office Supplies      24.034439
#             Technology           89.152458

# %%
# Write your code below here & exec!
avg_profit_per_category = data_superstore.groupby(['category','segment']).agg(rataan_profit = ('profit', 'mean'))

display(avg_profit_per_category)
# Out:
#                              rataan_profit
# category        segment
# Furniture       Consumer          6.281293
#                 Corporate        11.741201
#                 Home Office      10.705465
# Office Supplies Consumer         18.014174
#                 Corporate        22.102923
#                 Home Office      24.034439
# Technology      Consumer         74.445646
#                 Corporate        79.723823
#                 Home Office      89.152458

# %% [markdown]
# **Written By :** <br>
# <a href="https://www.linkedin.com/in/zakkiya-yumna/"><img alt="Linked In Link" src="https://img.shields.io/badge/-Zakkiya%20A.%20Yumna-0072b1?style=for-the-badge&logo=None&logoColor=white" align="left"/></a>
#
# <br><br>**for :**
#
# <a href="https://dqlab.id/"><img src="https://dqlab.id/files/dqlab/cache/87e30118ebba5ec7d96f6ea8c9dcc10b_x_118_X_55.png" align="left" /></a>
